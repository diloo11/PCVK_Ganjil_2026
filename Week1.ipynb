# %% [markdown]
# <a href="https://colab.research.google.com/github/diloo11/PCVK_Ganjil_2026/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://i.pinimg.com/736x/1f/c5/21/1fc521a86c9486dfb3e1d7b78cb96c98.jpg",
        "https://i.pinimg.com/736x/8e/34/77/8e34776197235c3e68bda255979b0f17.jpg",
        "https://i.pinimg.com/736x/3b/e7/9f/3be79fad3c581540751b477337516772.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)    #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)                           #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=736x796>
# <PIL.Image.Image image mode=RGB size=736x462>
# <PIL.Image.Image image mode=RGB size=480x240>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = " ,tinggi," x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  240  x  240
# <PIL.Image.Image image mode=RGB size=240x240>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# %% [markdown]
# PERTANYAAN PRAKTIKUM D2
# 1. agar dapat melihat langsung gambar yang diedit
# 2. kebanyakan hanya menggunakan cv.
# np: komputasi numerik dan manipulasi array/matriks.
# pd: analisis dan pengolahan data berbentuk tabel.
# cv: pengolahan citra dan computer vision.
# skimage: algoritma dan transformasi geometris.
# image: menyimpan file gambar dasar.
# plt: visualisasi gambar, plot grafik, dan histogram.
# 3. untuk merubah ukuran gambar tersebut menjadi setengah ukuran aslinya, agar bisa disandingkan bersebelahan.
# 4. untuk memberikan warna putih pada garis. karena jika 3 warna utama dicampur sama rata akan menghasilkan warna putih yaitu 1:1:1 red green blue.
# 5. semakin banyak pixelnya akan semakin jelas resolusinya, contohnya jika resolusinya 640x480 maka akan ada 307,200 pixels, yang artinya gambar akan semakin jelas

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal pada gambar
for y in range (tinggi):
  image_3[y,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal pada gambar
for y in range (tinggi):
  x = int(y * lebar / tinggi)
  image_3[y,x] = [255,255,255]

for y in range (tinggi):
  x = int (lebar - 1 - (y * lebar / tinggi))
  image_3[y,x] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# garis horizontal di tengah dengan panjang 200 pixel
y_tengah = int(tinggi / 2)

for x in range(120, 170):
    image_3[y_tengah, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

ukuran_kotak = 50

x_awal = 60
y_awal = 80

for y in range(y_awal, y_awal + ukuran_kotak):
    for x in range(x_awal, x_awal + ukuran_kotak):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/Wahyu KTM.jpeg")
plt.imshow(img) #format warna BGR

# %%
img = cv2.imread("/content/drive/MyDrive/Wahyu KTM.jpeg")
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Konversi BGR ke RGB
plt.imshow(img2)

# %%
img_gray = cv2.imread("/content/drive/MyDrive/Wahyu KTM.jpeg", cv2.IMREAD_GRAYSCALE)

#Tanpa cmap
plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title("Tanpa cmap")

#Dengan cmap
plt.subplot(1,2,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Dengan cmap")

plt.imshow(img_gray, cmap="magma")

plt.show()

# %%
img = cv2.imread("/content/drive/MyDrive/Wahyu KTM.jpeg")
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Konversi BGR ke RGB
imgRGBsmall = cv2.resize(imgRGB, (400,250))
plt.imshow(imgRGBsmall)

imgBalik=cv2.flip(imgRGBsmall, 1)

#tampilkan ukuran canvas yang lebih besar
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(imgBalik)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

# plt.imshow(black_img)

# perhatikan koordinat titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384, 0), pt2=(510, 150),color=(0, 255, 0),thickness=10)

#plt.imshow(black_img)

cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
#plt.imshow(black_img)

cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
#plt.imshow(black_img)

cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)

cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
#plt.imshow(black_img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=  cv.LINE_AA)
plt.imshow(black_img)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

black_img2= np.zeros(shape=(512, 512, 3), dtype=np.int32)
plt.imshow(black_img2)

vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
pts = vertices.reshape((-1,1,2))
pts

cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/Wahyu KTM.jpeg")
cv2_imshow(img)

print("Resolusi gambar:", img.shape[1], "x", img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
# Resolusi gambar: 1280 x 720

# %%
from google.colab import files
uploaded = files.upload()
img = cv2.imread("Wahyu KTM1.jpeg")
cv2_imshow(img)
# Out:
#      <input type="file" id="files-62fa6522-7f7b-4c0c-87e5-8b70b12bb253" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62fa6522-7f7b-4c0c-87e5-8b70b12bb253">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("Wahyu KTM1.jpeg")

# sensor pertama
for y in range(300, 850):
    for x in range(140, 200):
        img[y, x] = [255, 255, 255]

# sensor kedua
for y in range(300, 600):
    for x in range(100, 130):
        img[y, x] = [255, 255, 255]

# sensor ketiga
for y in range(300, 750):
    for x in range(60, 95):
        img[y, x] = [255, 255, 255]

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x1280>

# %% [markdown]
# Practicum D3 Questions and answers
# 1. Without Matplotlib use BGR format, if use Matplotlib use RGB format.
# 2. int16 use 2 byte per pixel, if int32 use 4 byte.
# 3. It replaces OpenCV's native cv2.imshow(), which crashes in google colab due to the lack of an interactive desktop GUI, allowing images to render directly inline inside colab's output cells.
# 4. it imports the I/O module from the Scikit-images library to read images from local storage or web URLs, save images, and display imgages natively in RGB format.

# %% [markdown]
# Practicum Assignment D3
# 1. Figsize doesnt change pixel size of a image. It only set the size of the display when matplotlib display it.
# 2. Red-blue, green blue

# %%
#red blue
img_rb = imgRGB.copy()
img_rb[:, :, 1] = 0

#green blue
img_gb = imgRGB.copy()
img_gb[:, :, 0] = 0

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img_rb)
plt.title("Channel Red-Blue")

plt.subplot(1, 2, 2)
plt.imshow(img_gb)
plt.title("Channel Green-Blue")
plt.show()

# %% [markdown]
# 3. Image row 20-115, column 25-120

# %%
img_cropped = imgRGB[20:115, 25:120]

plt.imshow(img_cropped)
plt.title("Crop row 20-115, column 25-120")
plt.show()

# %% [markdown]
# 4. Image row 5-30, all column only in red channel

# %%
img_redcrop = imgRGB[5:30, :, 0]

plt.imshow(img_redcrop, cmap="gray")
plt.title("Row 5-30, All colum, Channel Red")
plt.show()

# %% [markdown]
# 5. Create 5 square of many size and color in one image

# %%
import numpy as np
import cv2 as cv
img_rndm = imgRGB.copy()

np.random.seed(42) #randomizer
for _ in range(5):
    pt1_x = np.random.randint(150, 300)
    pt1_y = np.random.randint(0, 500)
    w = np.random.randint(0, 90)
    h = np.random.randint(50, 135)
    color = (int(np.random.randint(0, 255)), int(np.random.randint(0, 255)), int(np.random.randint(0, 255)))

    cv.rectangle(img_rndm, pt1=(pt1_x, pt1_y), pt2=(pt1_x + w, pt1_y + h), color=color, thickness=-1)

plt.imshow(img_rndm)
plt.title("5 Random squares")
plt.show()

# %% [markdown]
# 6. Vertical Flip

# %%
img_vertical_flip = cv.flip(imgRGB, 0)

plt.imshow(img_vertical_flip)
plt.title("Vertical Flip")
plt.show()

# %% [markdown]
# 7. Face Rectangle & Circle

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
my_photo = cv2.imread("/content/Wahyu KTM (1).jpeg")
my_photo_rgb = cv2.cvtColor(my_photo, cv2.COLOR_BGR2RGB)


# square
cv2.rectangle(my_photo_rgb, pt1=(180, 430), pt2=(260, 550), color=(0, 255, 0), thickness=3)
# circle
cv2.circle(my_photo_rgb, center=(220, 480), radius=50, color=(0, 0, 255), thickness=3)

plt.imshow(my_photo_rgb)
plt.title("Face detect circle and s")
plt.show()

# %% [markdown]
# 8.  Rectangle on bottom left corner
# 9. File Name

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
kobe_photo = cv2.imread("/content/drive/MyDrive/Kobe.jpg")
kobe_photoRGB = cv2.cvtColor(kobe_photo, cv2.COLOR_BGR2RGB)
kobe_blue = kobe_photoRGB.copy()
kobe_blue[:, :, 0] = 0
cv2.rectangle(kobe_blue, pt1=(3, 650), pt2=(90, 740), color=(0,255,0), thickness = 3)

font = cv2.FONT_HERSHEY_SCRIPT_COMPLEX
cv2.putText(kobe_blue, text='Black Mamba', org=(100,720), fontFace=font, fontScale=2, color=(255,255,255), thickness=2, lineType=cv.LINE_AA)
plt.imshow(kobe_blue)
